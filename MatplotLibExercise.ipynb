# %% [markdown]
# <a href="https://colab.research.google.com/github/kingketan9/ApplicationsOfAI-Labs/blob/main/MatplotLibExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Exercise 1
#
# Follow along with these steps:
#
# Create a figure object called fig using plt.figure()
# Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# Exercise 2
#
# Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# Now plot (x,y) on both axes. And call your figure object to show it.

# %%
ax1.plot(x,y)
ax2.plot(x,y)
fig

# %% [markdown]
# Exercise 3
#
# Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:

# %%
ax1.plot(x,z)
ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
fig1

# %% [markdown]
# Exercise 4
#
# Use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
axes[0].plot(x,y,linestyle='--',color='blue')
axes[1].plot(x,z,linestyle='-',color='red')
fig
